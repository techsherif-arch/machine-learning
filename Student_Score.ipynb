# %%
import numpy as np  
import matplotlib.pyplot as plt
import pandas as pd 
from sklearn.model_selection import train_test_split  
from sklearn.linear_model import LinearRegression  
from sklearn.metrics import mean_squared_error, r2_score

# Load the dataset
data = pd.read_csv('C:/Users/sanja/Downloads/machine learning/student_scores.csv')

# Extract the feature (Hours) and target (Scores)
x = data[['Hours']].values  
y = data['Scores'].values  

# Splitting the data into training and testing sets
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=1/3, random_state=0)

# Creating and training the linear regression model
regressor = LinearRegression()  
regressor.fit(x_train, y_train) 

# Making predictions on both the training and testing sets
y_train_pred = regressor.predict(x_train)  
y_test_pred = regressor.predict(x_test)  

# Plotting the training data with the regression line
plt.scatter(x_train, y_train, color="green")   
plt.plot(x_train, y_train_pred, color="red")  
plt.title("Linear Regression on Student Scores Dataset - Training Data")  
plt.xlabel("Hours Studied")  
plt.ylabel("Score")  
plt.show()   

# Plotting the testing data with the regression line
plt.scatter(x_test, y_test, color="blue")   
plt.plot(x_train, y_train_pred, color="red")  
plt.title("Linear Regression on Student Scores Dataset - Testing Data")  
plt.xlabel("Hours Studied")  
plt.ylabel("Score")  
plt.show() 

# Outputting the coefficients, intercept, MSE, and R^2 score
print('Coefficients:', regressor.coef_)
print('Intercept:', regressor.intercept_)
print('Mean Squared Error:', mean_squared_error(y_test, y_test_pred))
print('Coefficient of Determination (R^2 Score):', r2_score(y_test, y_test_pred))
# Out:
# Coefficients: [9.69062469]
# Intercept: 2.5069547569547623
# Mean Squared Error: 25.463280738222547
# Coefficient of Determination (R^2 Score): 0.955570080138813
